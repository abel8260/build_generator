# %%
import pyautogui
pyautogui.PAUSE = 23

cont=2

while (cont < 301):

    cont= cont + 1;
    pyautogui.leftClick(23, 130)
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(250, 350)
    pyautogui.leftClick(800, 280)
    pyautogui.write("quarto " + str(cont))
    pyautogui.leftClick(900,365)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
    pyautogui.leftClick(23, 130)
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    pyautogui.leftClick(800, 280)
    pyautogui.write("ver red " + str(cont))
    pyautogui.leftClick(900,365)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
    pyautogui.leftClick(23, 130)
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    pyautogui.leftClick(800, 280)
    pyautogui.write("ver redo " + str(cont))
    pyautogui.leftClick(900,365)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
    pyautogui.leftClick(23, 130)    
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    pyautogui.leftClick(800, 280)
    pyautogui.write("ver custom save "+ str(cont))
    pyautogui.leftClick(900,365)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
    pyautogui.leftClick(23, 130)    
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    pyautogui.leftClick(800, 280)
    pyautogui.write("v boss finale " + str(cont))
    pyautogui.leftClick(900,365)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
    pyautogui.leftClick(23, 130)    
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    pyautogui.leftClick(800, 280)
    pyautogui.write("ver sala " + str(cont))
    pyautogui.leftClick(900,365)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
    pyautogui.leftClick(23, 130)    
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    pyautogui.leftClick(800, 280)
    pyautogui.write("ver  shop free " + str(cont))
    pyautogui.leftClick(900,365)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
    pyautogui.leftClick(23, 130)    
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    pyautogui.leftClick(800, 280)
    pyautogui.write("ver shop paga " + str(cont))
    pyautogui.leftClick(900,365)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
    pyautogui.leftClick(23, 130)    

    
    
while (cont < 301):

    cont= cont + 1;
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(25, 100) 
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(900, 260)
    pyautogui.write("ver  shop free " + str(cont))
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(870, 350)
    pyautogui.write("normal")
    pyautogui.tripleClick(870, 415)
    pyautogui.write("quarto " + str(cont))
    pyautogui.tripleClick(870, 490)
    pyautogui.write("hotel_golden_star")
    pyautogui.press("enter")
    pyautogui.leftClick(25, 100) 
    pyautogui.leftClick(50, 50) 
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(900, 260)
    pyautogui.write("ver shop paga " + str(cont))
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(870, 350)
    pyautogui.write("normal")
    pyautogui.tripleClick(870, 415)
    pyautogui.write("quarto nn")
    pyautogui.tripleClick(870, 490)
    pyautogui.write("hotel_golden_star")
    pyautogui.press("enter")
    pyautogui.leftClick(25, 100) 
    pyautogui.leftClick(50, 50) 
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(900, 260)
    pyautogui.write("ver red " + str(cont))
    pyautogui.leftClick(25, 100) 
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(870, 350)
    pyautogui.write("normal")
    pyautogui.tripleClick(870, 415)
    pyautogui.write("quarto " + str(cont))
    pyautogui.tripleClick(870, 490)
    pyautogui.write("hotel_golden_star")
    pyautogui.press("enter")
    pyautogui.leftClick(25, 100)
    pyautogui.leftClick(50, 50)     
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(900, 260)
    pyautogui.write("ver redo " + str(cont))
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(870, 350)
    pyautogui.write("normal")
    pyautogui.tripleClick(870, 415)
    pyautogui.write("quarto " + str(cont))
    pyautogui.tripleClick(870, 490)
    pyautogui.write("hotel_golden_star")
    pyautogui.press("enter")
    pyautogui.leftClick(25, 100) 
    pyautogui.leftClick(50, 50)     
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(900, 260)
    pyautogui.write("ver sala " + str(cont))
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(870, 350)
    pyautogui.write("normal")
    pyautogui.tripleClick(870, 415)
    pyautogui.write("quarto " + str(cont)) 
    pyautogui.tripleClick(870, 490)
    pyautogui.write("hotel_golden_star")
    pyautogui.press("enter")
    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(25, 100) 
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(900, 260)
    pyautogui.write("ver  shop free " + str(cont))
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(870, 350)
    pyautogui.write("normal")
    pyautogui.tripleClick(870, 415)
    pyautogui.write("v boss finale " + str(cont))
    pyautogui.tripleClick(870, 490)
    pyautogui.write("hotel_golden_star")
    pyautogui.press("enter")    
    pyautogui.leftClick(25, 100) 
    pyautogui.leftClick(50, 50) 
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(900, 260)
    pyautogui.write("ver sala " + str(cont))
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.leftClick(900, 280)
    pyautogui.tripleClick(870, 350)
    pyautogui.write("normal")
    pyautogui.tripleClick(870, 415)
    pyautogui.write("quarto " + str(cont)) 
    pyautogui.tripleClick(870, 490)
    pyautogui.write("hotel_golden_star")
    pyautogui.press("enter")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 6>()
#      16 pyautogui.leftClick(800, 280)
#      17 pyautogui.write("quarto " + str(cont))
# ---> 18 pyautogui.leftClick(900,365)
#      19 pyautogui.write("normal")
#      20 pyautogui.leftClick(800, 465)
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:599, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     597 failSafeCheck()
#     598 returnVal = wrappedFunction(*args, **kwargs)
# --> 599 _handlePause(kwargs.get("_pause", True))
#     600 return returnVal
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:643, in _handlePause(_pause)
#     641 if _pause:
#     642     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 643     time.sleep(PAUSE)
#
# KeyboardInterrupt:
