# %%
import pyautogui
pyautogui.PAUSE = 3

# %%
def voltador():
    pyautogui.leftClick(25, 100)
def inicializador():
    pyautogui.PAUSE = 3

    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(250, 350)
    
def preenche_quarto():
    pyautogui.leftClick(800, 280)
    pyautogui.write("quarto n")
    pyautogui.leftClick(800, 362)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
inicializador()
preenche_quarto()
voltador()
voltador()

# %%
def voltador():
    pyautogui.leftClick(25, 100)
def inicializador():
    pyautogui.PAUSE = 3

    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    
def preenche_quarto():
    pyautogui.leftClick(800, 280)
    pyautogui.write("verificar red 1")
    pyautogui.leftClick(800, 362)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
inicializador()
preenche_quarto()
voltador()
voltador()

# %%
def voltador():
    pyautogui.leftClick(25, 100)
def inicializador():
    pyautogui.PAUSE = 3

    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    
def preenche_quarto():
    pyautogui.leftClick(800, 280)
    pyautogui.write("verificar redo 1")
    pyautogui.leftClick(800, 362)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
inicializador()
preenche_quarto()
voltador()
voltador()

# %%
def voltador():
    pyautogui.leftClick(25, 100)
def inicializador():
    pyautogui.PAUSE = 3

    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    
def preenche_quarto():
    pyautogui.leftClick(800, 280)
    pyautogui.write("verificar custom save")
    pyautogui.leftClick(800, 362)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
inicializador()
preenche_quarto()
voltador()
voltador()

# %%
def voltador():
    pyautogui.leftClick(25, 100)
def inicializador():
    pyautogui.PAUSE = 3

    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    
def preenche_quarto():
    pyautogui.leftClick(800, 280)
    pyautogui.write("verificar boss finale 1")
    pyautogui.leftClick(800, 362)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
inicializador()
preenche_quarto()
voltador()
voltador()

# %%
def voltador():
    pyautogui.leftClick(25, 100)
def inicializador():
    pyautogui.PAUSE = 3

    pyautogui.leftClick(50, 50)
    pyautogui.leftClick(150, 630)
    pyautogui.leftClick(500, 200)
    pyautogui.leftClick(390, 150)
    pyautogui.leftClick(1000, 550)
    pyautogui.leftClick(700, 360)
    
def preenche_quarto():
    pyautogui.leftClick(800, 280)
    pyautogui.write("verificar sala 1")
    pyautogui.leftClick(800, 362)
    pyautogui.write("normal")
    pyautogui.leftClick(800, 465)
    pyautogui.write("hotel_golden_star")
    pyautogui.press('enter')
inicializador()
preenche_quarto()
voltador()
voltador()

# %%
def voltador():
    pyautogui.leftClick(25, 100) 
    
def linkagem_quarto():
    pyautogui.leftClick(800, 280)
    

pyautogui.leftClick(50, 50)    
voltador() 
voltador()
voltador()    
linkagem_quarto()
